# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor, GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# 1: Data preprocessing
url = "https://raw.githubusercontent.com/kanblin/urban-octo-garbanzo/main/realest.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      156 non-null    float64
#  1   Bedroom    156 non-null    float64
#  2   Space      146 non-null    float64
#  3   Room       156 non-null    float64
#  4   Lot        146 non-null    float64
#  5   Tax        147 non-null    float64
#  6   Bathroom   156 non-null    float64
#  7   Garage     156 non-null    float64
#  8   Condition  156 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
df.describe().T
# Out:
#            count         mean         std    min     25%    50%     75%  \
# Price      156.0    56.474359   12.875307   32.0   46.00   55.0    65.0
# Bedroom    156.0     3.166667    1.348037    1.0    2.00    3.0     4.0
# Space      146.0  1097.246575  462.540698  539.0  805.25  965.5  1220.5
# Room       156.0     6.500000    1.675247    4.0    5.00    6.0     7.0
# Lot        146.0    32.808219    8.457859   24.0   25.00   30.0    37.0
# Tax        147.0   911.707483  443.263430  418.0  652.50  821.0  1012.5
# Bathroom   156.0     1.480769    0.529408    1.0    1.00    1.5     2.0
# Garage     156.0     0.846154    0.808454    0.0    0.00    1.0     1.5
# Condition  156.0     0.230769    0.422682    0.0    0.00    0.0     0.0
#
#               max
# Price        90.0
# Bedroom       8.0
# Space      2295.0
# Room         12.0
# Lot          50.0
# Tax        2752.0
# Bathroom      3.0
# Garage        2.0
# Condition     1.0

# %%
# Remove the last row with empty values.
df=df.iloc[0:156,0:9]
df.tail()
# Out:
#      Price  Bedroom  Space  Room   Lot    Tax  Bathroom  Garage  Condition
# 151   42.0      3.0  585.0   5.0  50.0  713.0       1.0     0.0        0.0
# 152   44.0      3.0  820.0   5.0  27.0    NaN       1.0     0.0        1.0
# 153   43.0      2.0  593.0   4.0  30.0  465.0       2.0     1.0        0.0
# 154   53.0      3.0  716.0   6.0  30.0  585.0       1.0     2.0        1.0
# 155   62.0      4.0  951.0   7.0  30.0  895.0       2.0     1.0        0.0

# %%
# Count the number of empty values each column.
df.isna().sum()
# Out:
# Price         0
# Bedroom       0
# Space        10
# Room          0
# Lot          10
# Tax           9
# Bathroom      0
# Garage        0
# Condition     0
# dtype: int64

# %%
# Replace the empty values with mean for numerical values and with empty for categorical values
for col in ['Space', 'Tax', 'Lot', 'Price']:
    df[col] = df[col].fillna(df[col].mean())

for col in ['Bedroom', 'Room', 'Bathroom', 'Garage', 'Condition']:
    df[col] = df[col].fillna(df[col].median())

# %%
# Count the number of empty values each column.
df.isna().sum()
# Out:
# Price        0
# Bedroom      0
# Space        0
# Room         0
# Lot          0
# Tax          0
# Bathroom     0
# Garage       0
# Condition    0
# dtype: int64

# %%
# 2: Implement feature engineering from scratch.
# Create new features based on existing features
df['TotalRooms'] = df['Bedroom'] + df['Bathroom'] + df['Room']
df['PricePerRoom'] = df['Price'] / df['TotalRooms']
# Calculate the ratio of lot size to living space
df['LotSpaceRatio'] = df['Lot'] / df['Space']
# Calculate the tax per room
df['TaxPerRoom'] = df['Tax'] / df['Room']
# Calculate the price per bedroom
df['PricePerBedroom'] = df['Price'] / df['Bedroom']
# Calculate the number of bathrooms per bedroom
df['BathroomPerBedroom'] = df['Bathroom'] / df['Bedroom']
df.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition  \
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
#
#    TotalRooms  PricePerRoom  LotSpaceRatio  TaxPerRoom  PricePerBedroom  \
# 0         8.5      6.235294       0.040331  130.400000        26.500000
# 1         8.0      6.875000       0.040491  200.000000        27.500000
# 2         9.5      5.894737       0.038889  179.400000        18.666667
# 3        10.5      5.523810       0.023833  160.666667        19.333333
# 4        11.5      5.565217       0.045455  157.000000        21.333333
#
#    BathroomPerBedroom
# 0                0.75
# 1                0.50
# 2                0.50
# 3                0.50
# 4                0.50

# %%
# 3: Data exploration
list_columns = list(df.columns)
plt.figure(figsize = (12,20))
for i in range(len(list_columns)):
    plt.subplot(5, 3, i + 1)
    plt.title(list_columns[i])
    plt.hist(df[list_columns[i]])
    
plt.tight_layout()

# %%
# Using correlation to find the features that are most closely related to the price
corr = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation between Features",fontsize=20)
plt.show()

# %%
# Visualizing the relationship between price and total number of rooms
sns.scatterplot(x='TotalRooms', y='Price', data=df)
plt.title("Total Rooms vs Price", fontsize=16)
plt.xlabel("Total Rooms", fontsize=14)
plt.ylabel("Price ($)", fontsize=14)
plt.show()

# %%
target_column = 'Price'
# Calculate the baseline prediction as the mean of the target variable
baseline_prediction = df[target_column].mean()

# Create a NumPy array for the baseline predictions (for comparison with test_labels)
baseline_preds = np.full_like(df[target_column], fill_value=baseline_prediction)

# Calculate baseline errors and display average baseline error
baseline_errors = abs(baseline_preds - df[target_column])
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# Average baseline error:  10.48

# %%
X = df.drop('Price', axis = 1)
y = df['Price']

# %%
# 4: Split the training set and test set
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# 5: Modeling with linear regression
from sklearn.linear_model import LinearRegression

# Build a simple linear regression model using any library
# Split the data into train and test sets

# Fit the model
lm = LinearRegression()
lm.fit(xtrain, ytrain)

# Make predictions on the test set
y_pred = lm.predict(xtest)

# Evaluate the model
print("Mean Squared Error: ", mean_squared_error(ytest, y_pred))
print("R-squared: ", r2_score(ytest, y_pred))

# 4: Predict and visualize the results

# Plot the predicted values against the actual values
plt.scatter(ytest, y_pred)
plt.plot(ytest, ytest, color='red')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()

# Visualize the distribution of errors
sns.displot((ytest-y_pred), bins=50)
plt.title("Distribution of Errors")
plt.xlabel("Error")
plt.show()
# Out:
# Mean Squared Error:  4.363574813217971
# R-squared:  0.9708089670235694
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 6: Modeling with decision tree

def calculate_mse(data, target_column='Price'):
    if len(data) == 0:
        return 0
    mean_value = data[target_column].mean()
    return ((data[target_column] - mean_value) ** 2).sum() / len(data)

def split_data(data, feature, value):
    left = data[data[feature] <= value]
    right = data[data[feature] > value]
    return left, right

def find_best_split(data):
    features = data.columns[:-1]  # Exclude the target variable
    best_mse = float('inf')
    best_split = None

    for feature in features:
        unique_values = data[feature].unique()
        for value in unique_values:
            left, right = split_data(data, feature, value)
            mse = len(left) * calculate_mse(left) + len(right) * calculate_mse(right)

            if mse < best_mse:
                best_mse = mse
                best_split = (feature, value)

    print("Best Split:", best_split)
    return best_split

def build_regression_tree(data, depth=0, max_depth=None):
    # Stop if max depth is reached or if all samples have the same price
    if max_depth is not None and depth == max_depth:
        return data['Price'].mean()

    if len(data['Price'].unique()) == 1:
        return data['Price'].iloc[0]

    # Find the best split and create sub-trees
    best_split = find_best_split(data)
    if best_split is None:
        return data['Price'].mean()

    feature, value = best_split
    left_data, right_data = split_data(data, feature, value)

    left_branch = build_regression_tree(left_data, depth + 1, max_depth)
    right_branch = build_regression_tree(right_data, depth + 1, max_depth)

    return (feature, value, left_branch, right_branch)

# Build the regression tree using the training data
recombine = pd.concat([xtrain, ytrain], axis=1)

# print(xtrain)
# print(ytrain)
# print(recombine)
tree = build_regression_tree(recombine, max_depth=3)
print("Regression Tree:", tree)
# Out:
# Best Split: ('TotalRooms', 14.0)
# Best Split: ('PricePerBedroom', 15.0)
# Best Split: ('Tax', 584.0)
# Best Split: ('Space', 874.0)
# Best Split: ('Tax', 1074.0)
# Best Split: ('Space', 1299.0)
# Best Split: ('Space', 2240.0)
# Regression Tree: ('TotalRooms', 14.0, ('PricePerBedroom', 15.0, ('Tax', 584.0, 36.666666666666664, 47.26923076923077), ('Space', 874.0, 50.36363636363637, 60.55555555555556)), ('Tax', 1074.0, ('Space', 1299.0, 72.0, 81.0), ('Space', 2240.0, 85.66666666666667, 88.66666666666667)))

# %%
def plot_regression_tree(tree, indent=""):
    if not isinstance(tree, tuple):
        print(f"Predicted Value: {tree:.2f}")
        return

    feature, value, left_branch, right_branch = tree
    print(f"{indent}{feature} <= {value:.2f}")
    
    plot_regression_tree(left_branch, indent + "|   ")
    plot_regression_tree(right_branch, indent + "|   ")

plot_regression_tree(tree)
# Out:
# TotalRooms <= 14.00
# |   PricePerBedroom <= 15.00
# |   |   Tax <= 584.00
# Predicted Value: 36.67
# Predicted Value: 47.27
# |   |   Space <= 874.00
# Predicted Value: 50.36
# Predicted Value: 60.56
# |   Tax <= 1074.00
# |   |   Space <= 1299.00
# Predicted Value: 72.00
# Predicted Value: 81.00
# |   |   Space <= 2240.00
# Predicted Value: 85.67
# Predicted Value: 88.67

# %%
def predict(instance, tree):
    if not isinstance(tree, tuple):
        return tree  # Reached a leaf node, return the predicted value
    feature, value, left_branch, right_branch = tree
    if instance[feature] <= value:
        return predict(instance, left_branch)
    else:
        return predict(instance, right_branch)

def evaluate_model(tree, test_data):
    predictions = [predict(instance, tree) for _, instance in test_data.iterrows()]
    actual_values = test_data['Price']

    # Calculate additional metrics
    r2_tree = r2_score(actual_values, predictions)
    mse_tree = mean_squared_error(actual_values, predictions)
    mae_tree = mean_absolute_error(actual_values, predictions)

    # Display a DataFrame with actual and predicted values
    result_df = pd.DataFrame({'Price': actual_values, 'Predicted': predictions})
    print(result_df)

    # Calculate and return MSE
    mse = calculate_mse(result_df, target_column='Price')
    return mse, r2_tree, mse_tree, mae_tree

# Evaluate the model on the testing set
test_data = pd.concat([xtest, ytest], axis=1)
mse_test, r2_test, mse_test_tree, mae_test_tree = evaluate_model(tree, test_data)

# Print additional metrics
print("Mean Squared Error on Testing Set:", mse_test)
print("R-squared on Testing Set:", r2_test)
print("Mean Squared Error (from sklearn) on Testing Set:", mse_test_tree)
print("Mean Absolute Error (from sklearn) on Testing Set:", mae_test_tree)
# Out:
#      Price  Predicted
# 26    54.0  60.555556
# 54    59.0  50.363636
# 37    45.0  47.269231
# 112   70.0  72.000000
# 24    50.0  50.363636
# 7     70.0  60.555556
# 45    35.0  36.666667
# 107   64.0  60.555556
# 137   70.0  60.555556
# 40    55.0  85.666667
# 90    50.0  50.363636
# 51    66.0  60.555556
# 108   63.0  60.555556
# 119   63.0  50.363636
# 56    65.0  60.555556
# 147   66.0  60.555556
# 33    70.0  60.555556
# 118   57.0  85.666667
# 44    64.0  60.555556
# 128   50.0  50.363636
# 145   59.0  50.363636
# 8     72.0  60.555556
# 139   85.0  85.666667
# 59    70.0  60.555556
# 111   73.0  60.555556
# 152   44.0  47.269231
# 85    71.0  60.555556
# 62    85.0  88.666667
# 83    41.0  47.269231
# 94    62.0  60.555556
# 16    62.0  60.555556
# 19    35.0  36.666667
# Mean Squared Error on Testing Set: 149.4833984375
# R-squared on Testing Set: 0.3607860255453853
# Mean Squared Error (from sklearn) on Testing Set: 95.55187723021712
# Mean Absolute Error (from sklearn) on Testing Set: 6.813434829059828

# %%
# Create a DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(random_state=0)
tree_reg3 = DecisionTreeRegressor(max_depth=3, random_state=0)

# Fit the model on the training data
tree_reg.fit(xtrain, ytrain)
tree_reg3.fit(xtrain, ytrain)

# Make predictions on the testing data
pred_tree = tree_reg.predict(xtest)
pred_tree3 = tree_reg3.predict(xtest)


# Evaluate the model
r2_tree = r2_score(ytest, pred_tree)
mse_tree = mean_squared_error(ytest, pred_tree)
mae_tree = mean_absolute_error(ytest, pred_tree)

# depth3
# r2_tree = r2_score(ytest, pred_tree3)
# mse_tree = mean_squared_error(ytest, pred_tree3)
# mae_tree = mean_absolute_error(ytest, pred_tree3)

# Print the evaluation metrics
print('R2 Score: ', r2_tree)
print("MSE: ", mse_tree)
print("MAE: ", mae_tree)
# Out:
# R2 Score:  0.47506712571290444
# MSE:  78.46875
# MAE:  4.59375

# %%
# 7: Modeling with random forest

rf = RandomForestRegressor(random_state = 0)

rf.fit(xtrain, ytrain)
pred_rf = rf.predict(xtest)

print('R2 Score: ', r2_score(ytest, pred_rf))
print("MSE: ", mean_squared_error(ytest, pred_rf))
print("MAE: ", mean_absolute_error(ytest, pred_rf))
# Out:
# R2 Score:  0.8302907278321824
# MSE:  25.36871875000001
# MAE:  3.4318750000000007

# %%
# Get the feature importances
importances = rf.feature_importances_
# Plot the importance of features
plt.bar(x=X.columns, height=importances)
plt.title("Feature Importance for Predicting Housing Price")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.xticks([col for col in range(len(importances))], X.columns, rotation="vertical")
plt.show()

# %%
# Update the model with only the important features
X = df[["Space", "Room", "Lot", "TotalRooms", "PricePerRoom", "TaxPerRoom", "PricePerBedroom", "Bathroom", "LotSpaceRatio", "Garage"]]
y = df['Price']
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 0)
rf = RandomForestRegressor(random_state = 0)

rf.fit(xtrain, ytrain)
pred_rf = rf.predict(xtest)

print('R2 Score: ', r2_score(ytest, pred_rf))
print("MSE: ", mean_squared_error(ytest, pred_rf))
print("MAE: ", mean_absolute_error(ytest, pred_rf))
# Out:
# R2 Score:  0.8488626062415481
# MSE:  22.592531250000004
# MAE:  3.4231250000000006

# %%
gb = GradientBoostingRegressor(random_state = 0)

gb.fit(xtrain, ytrain)
pred_gb = gb.predict(xtest)

print('R2 Score: ', r2_score(ytest, pred_gb))
print("MSE: ", mean_squared_error(ytest, pred_gb))
print("MAE: ", mean_absolute_error(ytest, pred_gb))
# Out:
# R2 Score:  0.8443606062367308
# MSE:  23.265505510485717
# MAE:  3.013361156512217

# %%
et = ExtraTreesRegressor(random_state = 0)

et.fit(xtrain, ytrain)
pred_et = et.predict(xtest)

print('R2 Score: ', r2_score(ytest, pred_et))
print("MSE: ", mean_squared_error(ytest, pred_et))
print("MAE: ", mean_absolute_error(ytest, pred_et))
# Out:
# R2 Score:  0.9487459597180393
# MSE:  7.661628125000003
# MAE:  1.9153125000000006

# %%
plt.figure(figsize=(24, 16))
plot_tree(tree_reg, filled=True, feature_names=None, rounded=True, fontsize=10)
plt.show()
